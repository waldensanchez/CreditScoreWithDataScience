# %%
from DQR import DQR
from Preprocessing import Preprocessing

# Path to your dataset
file_path = 'train.csv'

# Initialize and use the DQR class
dqr_instance = DQR(file_path)
data = dqr_instance.load_data()
dqr_report = dqr_instance.dqr()
# Optionally, you can visualize graphs and metrics from the DQR
dqr_instance.graphs()
metrics_summary = dqr_instance.metrics()

# Initialize the preprocessing with the path to your data
preprocessing_instance = Preprocessing(file_path)

# Load the data
data = preprocessing_instance.load_data()

# Preprocess the data
preprocessed_data = preprocessing_instance.preprocess_data()

# Save the preprocessed data to a new file
#preprocessing_instance.save_preprocessed_data('path_to_preprocessed_data.csv')
# Out:
# e:\ITESO\9\Modelos de Credito\Proyecto 2\DQR.py:12: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(self.filepath)
# e:\ITESO\9\Modelos de Credito\Proyecto 2\Preprocessing.py:11: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(self.filepath)

# %%
preprocessed_data.groupby('Spent').count()
# Out:
#            ID  Customer_ID   Month   Name     Age     SSN  Occupation  \
# Spent
# 0.0    100000       100000  100000  90015  100000  100000      100000
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# Spent                                                           ...
# 0.0           100000                  84998             100000  ...
#
#        Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# Spent
# 0.0        100000            100000                    100000
#
#        Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# Spent
# 0.0                 98770                 100000               100000
#
#        Amount_invested_monthly  Monthly_Balance  Credit_Score  Payment_size
# Spent
# 0.0                      95521            98800        100000        100000
#
# [1 rows x 28 columns]

# %%
preprocessed_data
# Out:
#             ID Customer_ID  Month            Name  Age          SSN  \
# 56752  0x1628a  CUS_0x1000      1  Alistair Barrf   17  913-74-1218
# 56753  0x1628b  CUS_0x1000      2             NaN   17  913-74-1218
# 56754  0x1628c  CUS_0x1000      3  Alistair Barrf  17_  913-74-1218
# 56755  0x1628d  CUS_0x1000      4  Alistair Barrf   17  913-74-1218
# 56756  0x1628e  CUS_0x1000      5  Alistair Barrf   17  913-74-1218
# ...        ...         ...    ...             ...  ...          ...
# 99155  0x25afd   CUS_0xffd      4        Damouniq   29  832-88-8320
# 99156  0x25afe   CUS_0xffd      5        Damouniq   29  832-88-8320
# 99157  0x25aff   CUS_0xffd      6             NaN   29  832-88-8320
# 99158  0x25b00   CUS_0xffd      7        Damouniq  30_  832-88-8320
# 99159  0x25b01   CUS_0xffd      8        Damouniq   30  832-88-8320
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# ...

# %%
Annual_Income, Monthly_Inhand_Salary, Outstanding_Debt, Amount_invested_monthly, Monthly_Balance apply natural log
# Out:
#   Cell In[4], line 1
#     Annual_Income, Monthly_Inhand_Salary, Outstanding_Debt, Amount_invested_monthly, Monthly_Balance apply natural log
#                                                                                                      ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
preprocessed_data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Monthly_Balance', 'Credit_Score', 'Spent',
#        'Payment_size'],
#       dtype='object')

# %%
#Occupation, ID, Customer_ID, Month, Name, SSN, Type_of_Loan

# %%
import pandas as pd
a = pd.read_csv('train.csv')
a.Payment_Behaviour.unique()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_24980\2738223763.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   a = pd.read_csv('train.csv')
# array(['High_spent_Small_value_payments',
#        'Low_spent_Large_value_payments',
#        'Low_spent_Medium_value_payments',
#        'Low_spent_Small_value_payments',
#        'High_spent_Medium_value_payments', '!@9#%8',
#        'High_spent_Large_value_payments'], dtype=object)
