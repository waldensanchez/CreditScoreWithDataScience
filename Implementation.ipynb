# %%
from DQR import DQR
from Preprocessing import Preprocessing

# Path to your dataset
file_path = 'train.csv'

# Initialize and use the DQR class
dqr_instance = DQR(file_path)
data = dqr_instance.load_data()
dqr_report = dqr_instance.dqr()
# Optionally, you can visualize graphs and metrics from the DQR
dqr_instance.graphs()
metrics_summary = dqr_instance.metrics()

# Initialize the preprocessing with the path to your data
preprocessing_instance = Preprocessing(file_path)

# Load the data
data = preprocessing_instance.load_data()

# Preprocess the data
preprocessed_data = preprocessing_instance.preprocess_data()

# Save the preprocessed data to a new file
#preprocessing_instance.save_preprocessed_data('path_to_preprocessed_data.csv')
# Out:
# c:\Users\Administrator\Documents\ITESO\9no\Modelos de credito\Proyecto 2\DQR.py:12: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(self.filepath)
# c:\Users\Administrator\Documents\ITESO\9no\Modelos de credito\Proyecto 2\Preprocessing.py:12: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(self.filepath)

# %%
preprocessed_data['Score']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Administrator\Documents\ITESO\9no\Modelos de credito\Proyecto 2\implementation.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Documents/ITESO/9no/Modelos%20de%20credito/Proyecto%202/implementation.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> preprocessed_data['Score']
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Score'

# %%
preprocessed_data.head(1)
# Out:
#             ID Customer_ID  Month            Name Age          SSN Occupation  \
# 56752  0x1628a  CUS_0x1000      1  Alistair Barrf  17  913-74-1218     Lawyer
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 56752      30625.94              10.977137           1.757825  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# 56752         Bad           1562.91                26.612093
#
#       Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
# 56752          10.166667                    Yes             4.91545
#
#       Amount_invested_monthly               Payment_Behaviour  \
# 56752      244.75028300769162  Low_spent_Large_value_payments
#
#          Monthly_Balance Score
# 56752  252.9247932365056     0
#
# [1 rows x 28 columns]

# %%
Credit_Mix, Payment of min amount

# %%
Occupation, ID, Customer_ID, Month, Name, SSN, Type_of_Loan

# %%
import pandas as pd
a = pd.read_csv('train.csv')
len(a.Type_of_Loan.unique())
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29732\2696350507.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   a = pd.read_csv('train.csv')
# 6261
